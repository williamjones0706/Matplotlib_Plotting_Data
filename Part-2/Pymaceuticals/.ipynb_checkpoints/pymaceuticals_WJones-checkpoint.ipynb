# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data = pd.read_csv("data/mouse_drug_data.csv")
clinical_trial_data = pd.read_csv("data/clinicaltrial_data.csv")

# Get rid of duplicate mouse drug data
mouse_drug_data = mouse_drug_data.drop_duplicates(subset= "Mouse ID", keep=False)

# Combine the data into a single dataset
merged_data = pd.merge(clinical_trial_data, mouse_drug_data, on="Mouse ID")

# Display the data table for preview
merged_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint
mean_tumor_volume = merged_data.groupby(["Drug", "Timepoint"])["Tumor Volume (mm3)"].mean()
mean_tumor_volume = mean_tumor_volume.reset_index()
# Convert to DataFrame
mean_tumor_volume_df = pd.DataFrame(mean_tumor_volume)
# Preview DataFrame
mean_tumor_volume_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
sem_tumor_volume = merged_data.groupby(["Drug", "Timepoint"])["Tumor Volume (mm3)"].sem()
sem_tumor_volume = sem_tumor_volume.reset_index()
# Convert to DataFrame
sem_tumor_volume_df = pd.DataFrame(sem_tumor_volume)
# Preview DataFrame
sem_tumor_volume_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
mean_tumor_volume_pivot = mean_tumor_volume_df.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
# Preview that Reformatting worked
mean_tumor_volume_pivot.head()
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.168130  43.944859  47.470830  46.851818
# 10         48.938560  42.531957  49.335368  48.689881
# 15         50.891769  41.495061  51.448025  50.779059
# 20         53.127384  40.238325  53.970080  53.170334

# %%
# Minor Data Munging to Re-Format the Data Frames
sem_tumor_volume_pivot = sem_tumor_volume_df.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
# Preview that Reformatting worked
sem_tumor_volume_pivot.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.241842  0.482955  0.254830   0.188950
# 10         0.388701  0.720225  0.461474   0.263949
# 15         0.502024  0.770432  0.532904   0.370544
# 20         0.607412  0.786199  0.684670   0.533182

# %%
drugList = ["Capomulin", "Infubinol", "Ketapril", "Placebo"]
plotStyleDict = {"Capomulin":'ro:', 'Infubinol':'b^:', 'Ketapril':'gs:', 'Placebo': 'kd:'}

# Generate the Plot (with Error Bars)

fig1, ax1 = plt.subplots()
for drug in drugList:
    ax1.errorbar(mean_tumor_volume_pivot.index, mean_tumor_volume_pivot[drug], 
                 sem_tumor_volume_pivot[drug], fmt = plotStyleDict[drug])
ax1.legend(drugList)
plt.grid(True)
plt.title('Tumor Response to Treatment')
plt.xlabel('Treatment Duration (Days)')
plt.ylabel('Tumor Volume (mm3)')

#Save plot 
plt.savefig("TumorResponseToTreatment.png")
plt.show()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
mean_meta_sites_grouped = merged_data.groupby(["Drug","Timepoint"])["Metastatic Sites"].mean()

# Convert to DataFrame
mean_meta_sites_df = pd.DataFrame(mean_met_sites_grouped).reset_index()
# Preview DataFrame
mean_meta_sites_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
sem_meta_sites_grouped = merged_data.groupby(["Drug","Timepoint"])["Metastatic Sites"].sem()
# Convert to DataFrame
sem_meta_sites_df = pd.DataFrame(sem_meta_sites_grouped).reset_index()
# Preview DataFrame
sem_meta_sites_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.074833
# 2  Capomulin         10          0.125433
# 3  Capomulin         15          0.132048
# 4  Capomulin         20          0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
meta_sites_bytime = mean_meta_sites_df.pivot(index="Timepoint",columns="Drug",values="Metastatic Sites")
sem_meta_sites = sem_meta_sites_df.pivot(index="Timepoint",columns="Drug",values="Metastatic Sites")
# Preview that Reformatting worked
meta_sites_bytime.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.347826  0.120000  0.260870   0.166667
# 10         0.619048  0.250000  0.523810   0.500000
# 15         0.800000  0.333333  0.809524   0.809524
# 20         1.000000  0.347826  0.947368   1.294118

# %%
# Generate the Plot (with Error Bars)
fig2, ax2 = plt.subplots()
for drug in drugList:
    ax2.errorbar(meta_sites_bytime.index, meta_sites_bytime[drug],
             sem_meta_sites[drug], fmt=plotStyleDict[drug])

ax2.legend(drugList)
plt.grid(True)
plt.title('Metastatic Spread during Treatment')
plt.xlabel('Treatment Duration (Days)')
plt.ylabel('Metastatic Sites')


# Save the Figure
plt.savefig("MetastaticSpreadDuringTreatment.png")
# Show the Figure
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
mouse_count = merged_data.groupby(["Drug", "Timepoint"])['Mouse ID'].count()
# Convert to DataFrame
mouse_count_df = pd.DataFrame(mouse_count).reset_index()
mouse_count_df = mouse_count_df.rename(columns={"Mouse ID": "Mouse Count"})
# Preview DataFrame
mouse_count_df.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames
mouse_count_bytime = mouse_count_df.pivot(index="Timepoint", columns="Drug", values="Mouse Count")
# Preview the Data Frame
mouse_count_bytime.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                24        25        24         25
# 5                23        25        23         24
# 10               21        24        21         22
# 15               15        24        21         21
# 20               15        23        19         17

# %%
# Generate the Plot (Accounting for percentages)
mouseSurvivalRate = pd.DataFrame()
for col in mouse_count_bytime.columns:
    mouseSurvivalRate[col] = 100 * (mouse_count_bytime[col]/25)

fig3, ax3 = plt.subplots()
for drug in drugList:
    plt.plot(mouseSurvivalRate.index, mouseSurvivalRate[drug], plotStyleDict[drug])
plt.grid(True)
ax3.legend(drugList)
plt.title("Survival During Treatment")
plt.xlabel("Treatment Duration (Days)")
plt.ylabel("Survival Rate (%)")

# Save the Figure
plt.savefig("SurvivalDuringTreatment.png")
# Show the Figure
plt.show()

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
percent_change_drug = (mean_tumor_volume_pivot.iloc[9,:] - mean_tumor_volume_pivot.iloc[0,:])/mean_tumor_volume_pivot.iloc[0,:] *100
# Display the data to confirm
print(percent_change_drug)
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple
percent_change = percent_change_drug.to_frame()
percent_change = percent_change.rename(columns = {0 : "Percent Change"})
percent_change["Pass"] = (percent_change < 0)

# Splice the data between passing and failing drugs
# Orient widths. Add labels, tick marks, etc. 
# Use functions to label the percentages of changes
# Call functions to implement the function calls
fig4, ax4 = plt.subplots()
x = 0

for drug in drugList:
    y = percent_change.loc[drug, "Percent Change"]
    if percent_change.loc[drug, "Pass"] == True:
        ax4.bar(drug, y, width = .9, color = "g")
        plt.text(x-.25, -5, '{:.0f}%'.format(y), color = "white")
    else:
        ax4.bar(drug, y, width = .9, color = "r")
        plt.text(x-.2, 2, '{:.0f}%'.format(y), color = "black")
    x = 1 + x
plt.yticks((-20, 0, 20, 40, 60))
ax4.yaxis.grid()
plt.title("Mean Tumor Change over 45 Day Trial")
plt.ylabel("% Change Tumor Volume")
plt.ylim(ymax = 65)

# Save the Figure
plt.savefig("MeanTumorChange.png")

# Show the Figure
plt.show()
