# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x2c91a863a58>,
#   <matplotlib.axis.XTick at 0x2c91a863390>,
#   <matplotlib.axis.XTick at 0x2c91a863240>,
#   <matplotlib.axis.XTick at 0x2c91a906358>,
#   <matplotlib.axis.XTick at 0x2c91a906828>,
#   <matplotlib.axis.XTick at 0x2c91a906da0>,
#   <matplotlib.axis.XTick at 0x2c91a90c358>,
#   <matplotlib.axis.XTick at 0x2c91a90c8d0>,
#   <matplotlib.axis.XTick at 0x2c91a90ce48>,
#   <matplotlib.axis.XTick at 0x2c91a915400>,
#   <matplotlib.axis.XTick at 0x2c91a915978>,
#   <matplotlib.axis.XTick at 0x2c91a915ef0>,
#   <matplotlib.axis.XTick at 0x2c91a90c978>,
#   <matplotlib.axis.XTick at 0x2c91a906400>,
#   <matplotlib.axis.XTick at 0x2c91a91b518>,
#   <matplotlib.axis.XTick at 0x2c91a91ba90>,
#   <matplotlib.axis.XTick at 0x2c91a9220b8>,
#   <matplotlib.axis.XTick at 0x2c91a9225c0>,
#   <matplotlib.axis.XTick at 0x2c91a922b38>,
#   <matplotlib.axis.XTick at 0x2c91a92a160>,
#   <matplotlib.axis.XTick at 0x2c91a92a668>,
#   <matplotlib.axis.XTick at 0x2c91a9229b0>,
#   <matplotlib.axis.XTick at 0x2c91a9066a0>,
#   <matplotlib.axis.XTick at 0x2c91a92ab00>,
#   <matplotlib.axis.XTick at 0x2c91a931128>,
#   <matplotlib.axis.XTick at 0x2c91a931630>,
#   <matplotlib.axis.XTick at 0x2c91a931ba8>,
#   <matplotlib.axis.XTick at 0x2c91a935198>,
#   <matplotlib.axis.XTick at 0x2c91a9356d8>,
#   <matplotlib.axis.XTick at 0x2c91a935c50>,
#   <matplotlib.axis.XTick at 0x2c91a9356a0>,
#   <matplotlib.axis.XTick at 0x2c91a9316d8>,
#   <matplotlib.axis.XTick at 0x2c91a922588>,
#   <matplotlib.axis.XTick at 0x2c91a941710>,
#   <matplotlib.axis.XTick at 0x2c91a941c88>,
#   <matplotlib.axis.XTick at 0x2c91a948240>,
#   <matplotlib.axis.XTick at 0x2c91a9487b8>,
#   <matplotlib.axis.XTick at 0x2c91a948d30>,
#   <matplotlib.axis.XTick at 0x2c91a9502e8>,
#   <matplotlib.axis.XTick at 0x2c91a950860>,
#   <matplotlib.axis.XTick at 0x2c91a948898>,
#   <matplotlib.axis.XTick at 0x2c91a9417f0>,
#   <matplotlib.axis.XTick at 0x2c91a950940>,
#   <matplotlib.axis.XTick at 0x2c91a950f60>,
#   <matplotlib.axis.XTick at 0x2c91a953518>,
#   <matplotlib.axis.XTick at 0x2c91a953a90>,
#   <matplotlib.axis.XTick at 0x2c91a95e0b8>,
#   <matplotlib.axis.XTick at 0x2c91a95e5c0>,
#   <matplotlib.axis.XTick at 0x2c91a95eb38>,
#   <matplotlib.axis.XTick at 0x2c91a95e668>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the graph
plt.tight_layout()
plt.savefig("Images/avg_state_rain_WJones.png")
plt.show()
